# %% [markdown]
# # 🔹 1. подтягивание файлов из git через curl wget
#
# ## Что должно стоять
# ```bash
# sudo apt update && sudo apt install -y wget curl unzip git jupyter
# ```
# ## Создать структуру папок
# ```bash
# mkdir -p ~/files
# cd ~/files
# pwd
# ```
#
# ## Скачать файл
# ```bash
# # Вариант 1: wget
# wget https://raw.githubusercontent.com/NiksKSS/Preparing_Rea2026/main/Docker/docker.ipynb
#
# # Вариант 2: curl
# curl -L -O https://raw.githubusercontent.com/NiksKSS/Preparing_Rea2026/main/Docker/docker.ipynb
# ```
#
# ## Проверить результат
# ```bash
# ls -la docker.ipynb
# file docker.ipynb
# ```
#
# ## Запустить Jupyter
# ```bash
# jupyter notebook docker.ipynb
# ```
#
#
# ## Чистка
# ```bash
# rm -f docker.ipynb
# ```

# %% [markdown]
# # 🔹 Настройка оборудования
#
# Проверим ОС
#
# ```bash
# uname -a
# ```
#
# ---
#
# # 1. Обновление системы
#
# ```bash
# sudo apt update
# sudo apt upgrade -y
# ```
#
# ---
#
# # 2. Базовые пакеты
#
# ```bash
# sudo apt install -y \
#   curl \
#   wget \
#   git \
#   build-essential \
#   ca-certificates \
#   software-properties-common
# ```
#
# ---
#
# # 3. Установка Python
#
# Проверка:
#
# ```bash
# python3 --version
# ```
#
# Если **не найден**:
#
# ```bash
# sudo apt install -y python3 python3-pip python3-venv
# ```
#
# Проверка:
#
# ```bash
# python3 --version
# pip3 --version
# ```
#
# ---
#
# # 4. Установка VS Code
#
#
# ```bash
# wget -qO- https://packages.microsoft.com/keys/microsoft.asc | gpg --dearmor > microsoft.gpg
# sudo install -o root -g root -m 644 microsoft.gpg /etc/apt/trusted.gpg.d/
#
# sudo sh -c 'echo "deb [arch=amd64] https://packages.microsoft.com/repos/code stable main" > /etc/apt/sources.list.d/vscode.list'
#
# sudo apt update
# sudo apt install -y code
# ```
#
# Запуск:
#
# ```bash
# code
# ```
#
# ---
#
# # 5. Расширения VS Code
#
# В VS Code → **Ctrl+Shift+X**, установить:
#
# * **Python** (Microsoft)
# * **Pylance**
# * **Jupyter**
# * **Jupyter Notebook Renderers**
# * **Docker** (Microsoft)
# * **YAML**
#
# Перезапусти VS Code.
#
# ---
#
# # 6. Создание проекта и виртуального окружения
#
# ```bash
# mkdir Rea
# cd Rea
# ```
#
# Создаём виртуальное окружение:
#
# ```bash
# python3 -m venv rea
# ```
#
# Активируем:
#
# ```bash
# source rea/bin/activate
# ```
#
# Если видим:
#
# ```text
# (rea) user@pc:~/Rea$
# ```
#
# то ок
#
# ---
#
# # 7. Обновление pip внутри rea
#
# ```bash
# pip install --upgrade pip
# ```
#
# ---
#
# # 8. Установка Jupyter и регистрация ядра
#
# ```bash
# pip install jupyter notebook ipykernel
# ```
#
# ```bash
# python -m ipykernel install --user --name=rea --display-name "Python (rea)"
# ```
#
# ---
#
# # 9. Установка нужных в перспективе  библиотек
#
#
# ```bash
# pip install \
# numpy \
# pandas \
# scipy \
# scikit-learn \
# matplotlib \
# seaborn \
# plotly \
# statsmodels \
# xgboost \
# lightgbm \
# catboost \
# imbalanced-learn \
# optuna \
# shap \
# tqdm \
# joblib \
# pyarrow \
# openpyxl \
# xlrd \
# pillow \
# opencv-python \
# albumentations \
# imageio \
# librosa \
# soundfile \
# torch \
# torchvision \
# torchaudio \
# tensorflow \
# keras \
# transformers \
# datasets \
# evaluate \
# accelerate \
# spacy \
# nltk \
# gensim \
# fasttext \
# sentencepiece \
# torchmetrics \
# pytorch-lightning \
# onnx \
# onnxruntime \
# wandb \
# mlflow
# ```
#
# ---
#
# # НА ПОТОМ:
#
# # 11. Установка Docker
#
# ## 11.1 Удаляем старый мусор
#
# ```bash
# sudo apt remove -y docker docker-engine docker.io containerd runc
# ```
#
# ## 11.2 Добавляем репозиторий Docker
#
# ```bash
# sudo apt update
# sudo apt install -y ca-certificates curl gnupg
#
# sudo install -m 0755 -d /etc/apt/keyrings
# curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /etc/apt/keyrings/docker.gpg
#
# echo \
#   "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.gpg] https://download.docker.com/linux/ubuntu \
#   $(. /etc/os-release && echo "$VERSION_CODENAME") stable" | \
#   sudo tee /etc/apt/sources.list.d/docker.list > /dev/null
# ```
#
# ## 11.3 Установка Docker
#
# ```bash
# sudo apt update
# sudo apt install -y docker-ce docker-ce-cli containerd.io docker-buildx-plugin docker-compose-plugin
# ```
#
# ## 11.4 Запуск и автозапуск
#
# ```bash
# sudo systemctl enable docker
# sudo systemctl start docker
# ```
#
# ## 11.5 Docker без sudo
#
# ```bash
# sudo usermod -aG docker $USER
# ```
#
#  **Выйnb из системы и зайnb снова**, иначе группа не применится.
#
# Проверка:
#
# ```bash
# docker run hello-world
# ```
#
# ---
#
# # 12. Установка Apache Airflow
#
#
# ## 12.1 Создаём папку под Airflow
#
# ```bash
# mkdir airflow
# cd airflow
# ```
#
# ## 12.2 Загружаем официальный docker-compose
#
# ```bash
# curl -LfO 'https://airflow.apache.org/docs/apache-airflow/stable/docker-compose.yaml'
# ```
#
# ## 12.3 Создаём необходимые папки
#
# ```bash
# mkdir -p ./dags ./logs ./plugins
# ```
#
# ## 12.4 Инициализация Airflow
#
# ```bash
# docker compose up airflow-init
# ```
#
# ## 12.5 Запуск Airflow
#
# ```bash
# docker compose up -d
# ```
#
# ---
#
# # 13. Вход в Airflow
#
# Открsnm браузер:
#
# ```
# http://localhost:8080
# ```
#
# Логин:
#
# ```
# airflow
# ```
#
# Пароль:
#
# ```
# airflow
# ```
#
# ---
#
# # 14. Запуск VS Code с проектом
#
# ```bash
# cd ~/Rea
# source rea/bin/activate
# code .
# ```
#
# ---
#
# # 15. Работа с Jupyter в VS Code
#
# * `Ctrl+Shift+P`
# * `Jupyter: Create New Blank Notebook`
# * Kernel → **Python (rea)**
#
#
# ---
#
# # 16. Как это всё запускать потом
#
# ### Airflow:
#
# ```bash
# cd Rea/airflow
# docker compose up -d
# ```
#
# ### Остановить Airflow:
#
# ```bash
# docker compose down
# ```
#
# ---
